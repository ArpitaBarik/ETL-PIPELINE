# %%
import requests
import polars as pl
import pandas as pd
import time

from urllib.parse import urlencode
from sqlalchemy import create_engine

# %%
CENSUS_API_URL = "https://api.census.gov/data/2022/acs/acs5"

CENSUS_API_KEY = "00200b6fdc213ea1ae3272478057c94cb3815637"

PARAMS = {
    "get": "NAME,B01003_001E",
    "for": "state:*",
    "key": CENSUS_API_KEY
}

full_url = CENSUS_API_URL + "?" + urlencode(PARAMS)
print("API URL:", full_url)
# Out:
# API URL: https://api.census.gov/data/2022/acs/acs5?get=NAME%2CB01003_001E&for=state%3A%2A&key=00200b6fdc213ea1ae3272478057c94cb3815637

# %%
response = requests.get(CENSUS_API_URL, params=PARAMS)
response.raise_for_status()

payload = response.json()

# Preview raw data
payload[:5]
# Out:
# [['NAME', 'B01003_001E', 'state'],
#  ['Alabama', '5028092', '01'],
#  ['Alaska', '734821', '02'],
#  ['Arizona', '7172282', '04'],
#  ['Arkansas', '3018669', '05']]

# %%
headers = payload[0]
rows = payload[1:]

df = pl.DataFrame(
    rows,
    schema=headers,
    orient="row"
)

df = df.rename({
    "NAME": "state_name",
    "B01003_001E": "total_population",
    "state": "state_code"
})

df = df.with_columns(
    pl.col("total_population").cast(pl.Int64, strict=False)
)

df.head()
# Out:
# shape: (5, 3)
# ┌────────────┬──────────────────┬────────────┐
# │ state_name ┆ total_population ┆ state_code │
# │ ---        ┆ ---              ┆ ---        │
# │ str        ┆ i64              ┆ str        │
# ╞════════════╪══════════════════╪════════════╡
# │ Alabama    ┆ 5028092          ┆ 01         │
# │ Alaska     ┆ 734821           ┆ 02         │
# │ Arizona    ┆ 7172282          ┆ 04         │
# │ Arkansas   ┆ 3018669          ┆ 05         │
# │ California ┆ 39356104         ┆ 06         │
# └────────────┴──────────────────┴────────────┘

# %%
DB_USER = "postgres"
DB_PASSWORD = "Barik@1010"
DB_HOST = "localhost"
DB_PORT = "5432"
DB_NAME = "census_db"

engine = create_engine(
    f"postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
)

engine
# Out:
# Engine(postgresql://postgres:***@1010@localhost:5432/census_db)

# %%
df_pandas = df.to_pandas()

df_pandas.to_sql(
    name="census_population",
    con=engine,
    if_exists="replace",
    index=False
)

print("Data loaded into PostgreSQL table: census_population")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_pandas = df.to_pandas()
#       3 df_pandas.to_sql(
#       4     name="census_population",
#       5     con=engine,
#       6     if_exists="replace",
#       7     index=False
#       8 )
#      10 print("Data loaded into PostgreSQL table: census_population")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\polars\dataframe\frame.py:2561, in DataFrame.to_pandas(self, use_pyarrow_extension_array, **kwargs)
#    2556 if Object in self.dtypes:
#    2557     return self._to_pandas_with_object_columns(
#    2558         use_pyarrow_extension_array=use_pyarrow_extension_array, **kwargs
#    2559     )
# -> 2561 return self._to_pandas_without_object_columns(
#    2562     self, use_pyarrow_extension_array=use_pyarrow_extension_array, **kwargs
#    2563 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\polars\dataframe\frame.py:2612, in DataFrame._to_pandas_without_object_columns(self, df, use_pyarrow_extension_array, **kwargs)
#    2609 if not df.width:  # Empty dataframe, cannot infer schema from batches
#    2610     return pd.DataFrame()
# -> 2612 record_batches = df._df.to_pandas()
#    2613 tbl = pa.Table.from_batches(record_batches)
#    2614 if use_pyarrow_extension_array:
#
# ModuleNotFoundError: No module named 'pyarrow'
